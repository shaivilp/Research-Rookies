# %%
import polars as pl
from datetime import datetime
import matplotlib.pyplot as plt
import json
import datetime

pl.Config().set_tbl_cols(100)
pl.Config().set_tbl_rows(30)
# Out:
# polars.config.Config

# %%
#Map route id to correct route name
route_mapping = {
    3: "2L",
    4: "2R",
    33: "3",
    17: "10",
    18: "11",
    23: "12",
    12: "16",
    13: "17",
    14: "18",
    30: "19",
    29: "21",
    38: "21 Tripper",
    777: "777"
}

# %%
preds = pl.read_parquet("2024-09-preds-start.parquet")

preds
# Out:
# shape: (1_666_098, 14)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ sto ┆ pat ┆ tim ┆ min ┆ tim ┆ sta ┆ sch ┆ schedu ┆ statu ┆ direc ┆ equip ┆ route ┆ recei ┆ __ind │
# │ pID ┆ ter ┆ ePo ┆ ute ┆ e   ┆ tus ┆ edu ┆ leNumb ┆ scolo ┆ tion  ┆ mentI ┆ ID    ┆ veTim ┆ ex_le │
# │ --- ┆ nSt ┆ int ┆ s   ┆ --- ┆ --- ┆ le  ┆ er     ┆ r     ┆ ---   ┆ D     ┆ ---   ┆ e     ┆ vel_0 │
# │ i64 ┆ opI ┆ --- ┆ --- ┆ str ┆ str ┆ --- ┆ ---    ┆ ---   ┆ cat   ┆ ---   ┆ i64   ┆ ---   ┆ __    │
# │     ┆ D   ┆ boo ┆ i64 ┆     ┆     ┆ str ┆ str    ┆ cat   ┆       ┆ str   ┆       ┆ datet ┆ ---   │
# │     ┆ --- ┆ l   ┆     ┆     ┆     ┆     ┆        ┆       ┆       ┆       ┆       ┆ ime[n ┆ i64   │
# │     ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆        ┆       ┆       ┆       ┆       ┆ s]    ┆       │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# ...

# %%
df = pl.read_parquet("2024-09-entries-start.parquet")
df = df.with_columns(pl.col("routeID").replace_strict(route_mapping))

df
# Out:
# shape: (1_564_484, 30)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ rou ┆ pat ┆ equ ┆ tri ┆ lat ┆ lng ┆ loa ┆ cap ┆ eLo ┆ blo ┆ nex ┆ nex ┆ nex ┆ h   ┆ las ┆ las ┆ sch ┆ inS ┆ onS ┆ tra ┆ rec ┆ aID ┆ cap ┆ dir ┆ seq ┆ las ┆ nex ┆ nex ┆ atS ┆ __i │
# │ teI ┆ ter ┆ ipm ┆ pID ┆ --- ┆ --- ┆ d   ┆ aci ┆ ad  ┆ ckI ┆ tSt ┆ tSt ┆ tPa ┆ --- ┆ tSt ┆ tPa ┆ edu ┆ erv ┆ che ┆ inI ┆ eiv ┆ --- ┆ tur ┆ ect ┆ --- ┆ tSt ┆ tSt ┆ tSt ┆ top ┆ nde │
# │ D   ┆ nID ┆ ent ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ ty  ┆ --- ┆ D   ┆ opI ┆ opE ┆ tte ┆ i64 ┆ opI ┆ tte ┆ leN ┆ ice ┆ dul ┆ D   ┆ eTi ┆ str ┆ eTi ┆ ion ┆ i64 ┆ opE ┆ opE ┆ opP ┆ --- ┆ x_l │
# │ --- ┆ --- ┆ ID  ┆ i64 ┆     ┆     ┆ i64 ┆ --- ┆ i64 ┆ --- ┆ D   ┆ TA  ┆ rnS ┆     ┆ D   ┆ rnS ┆ umb ┆ --- ┆ e   ┆ --- ┆ me  ┆     ┆ me  ┆ --- ┆     ┆ xtI ┆ xtI ┆ ctP ┆ boo ┆ eve │
# ...

# %%
# Load stops json
file = open("stops.json", "r")
stopsData = json.load(file)

stops = pl.DataFrame(stopsData['get_stops'])
stops
# Out:
# shape: (362, 8)
# ┌─────┬─────────┬─────┬───────────────────────────────┬───────────┬────────────┬───────┬───────────┐
# │ rid ┆ rsid    ┆ id  ┆ name                          ┆ lat       ┆ lng        ┆ extID ┆ shortName │
# │ --- ┆ ---     ┆ --- ┆ ---                           ┆ ---       ┆ ---        ┆ ---   ┆ ---       │
# │ i64 ┆ i64     ┆ i64 ┆ str                           ┆ f64       ┆ f64        ┆ str   ┆ str       │
# ╞═════╪═════════╪═════╪═══════════════════════════════╪═══════════╪════════════╪═══════╪═══════════╡
# │ 3   ┆ 197057  ┆ 449 ┆ Anderson Hall                 ┆ 41.938465 ┆ -88.761086 ┆ 449   ┆ 449       │
# │ 3   ┆ 197056  ┆ 448 ┆ Barsema Hall                  ┆ 41.939774 ┆ -88.761009 ┆ 448   ┆ 448       │
# │ 3   ┆ 197054  ┆ 446 ┆ Castle Dr. at College Ave.    ┆ 41.93412  ┆ -88.763115 ┆ 446   ┆ 446       │
# │ 3   ┆ 197053  ┆ 445 ┆ Castle Dr. at Montgomery      ┆ 41.9324   ┆ -88.762863 ┆ 445   ┆ 445       │
# ...

# %%
pattern_mapping = {
    3: "2L",
    4: "2R",
    37: "3",
    17: "10",
    18: "11",
    23: "12",
    12: "16",
    13: "17",
    14: "18",
    33: "19",
    46: "21",
    45: "21 Tripper",
}

# Load patterns json
file = open("patterns.json", "r")
patternsData = json.load(file)

patterns = pl.DataFrame(patternsData['get_patterns'])
patterns = patterns.with_columns(pl.col("id").replace_strict(pattern_mapping, default="None"))
patterns
# Out:
# shape: (12, 12)
# ┌────────┬────────┬───────┬──────┬────────┬────────┬───────┬───────┬───────┬───────┬───────┬───────┐
# │ id     ┆ name   ┆ extID ┆ type ┆ length ┆ color  ┆ encLi ┆ decLi ┆ route ┆ route ┆ stati ┆ stopI │
# │ ---    ┆ ---    ┆ ---   ┆ ---  ┆ ---    ┆ ---    ┆ ne    ┆ ne    ┆ s     ┆ Names ┆ ons   ┆ Ds    │
# │ str    ┆ str    ┆ str   ┆ i64  ┆ f64    ┆ str    ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │        ┆        ┆       ┆      ┆        ┆        ┆ str   ┆ list[ ┆ list[ ┆ list[ ┆ list[ ┆ list[ │
# │        ┆        ┆       ┆      ┆        ┆        ┆       ┆ null] ┆ i64]  ┆ str]  ┆ null] ┆ i64]  │
# ╞════════╪════════╪═══════╪══════╪════════╪════════╪═══════╪═══════╪═══════╪═══════╪═══════╪═══════╡
# │ 2L     ┆ Route  ┆ 2     ┆ 2    ┆ 5.1560 ┆ #09713 ┆ eq}~F ┆ []    ┆ [3]   ┆ ["Rou ┆ []    ┆ [433, │
# │        ┆ 2L     ┆       ┆      ┆ 97     ┆ 8      ┆ xix|O ┆       ┆       ┆ te    ┆       ┆ 465,  │
# ...

# %%
stops.rename({"id": "nextStopID"}).select(["nextStopID", "name"]).unique().sort("nextStopID")
# Out:
# shape: (240, 2)
# ┌────────────┬─────────────────────────────────┐
# │ nextStopID ┆ name                            │
# │ ---        ┆ ---                             │
# │ i64        ┆ str                             │
# ╞════════════╪═════════════════════════════════╡
# │ 431        ┆ Student Center                  │
# │ 432        ┆ DuSable Turnaround Rt 5 / Rt 1… │
# │ 433        ┆ Lincoln Hall                    │
# │ 436        ┆ Convocation Center Entrance 3   │
# │ 437        ┆ Lot C3 at Presidents Blvd       │
# │ 438        ┆ Norther View Circle             │
# │ 439        ┆ Lincoln Hwy. at High Meadows    │
# │ 440        ┆ Lincoln Hwy. at Culvers         │
# │ 441        ┆ Lincoln Hwy. at Precision Auto… │
# │ 442        ┆ Lincoln Hwy. at CVS Pharmacy    │
# │ 443        ┆ Lincoln Hwy. at Pizza Villa     │
# │ 444        ┆ Lincoln Hwy. at Psychology Bui… │
# │ 445        ┆ Castle Dr. at Montgomery        │
# │ 446        ┆ Castle Dr. at College Ave.      │
# ...

# %%
#Left join stops to get stop names for nextStopID and lastStopID
df = df.join(stops.rename({"id": "nextStopID"}).select(["nextStopID", "name"]).unique(), on="nextStopID", how="left").rename({"name": "nextStopName"})
df = df.join(stops.rename({"id": "lastStopID"}).select(["lastStopID", "name"]).unique(), on="lastStopID", how="left").rename({"name": "lastStopName"})

df
# Out:
# shape: (1_564_484, 32)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ rou ┆ pat ┆ equ ┆ tri ┆ lat ┆ lng ┆ loa ┆ cap ┆ eLo ┆ blo ┆ nex ┆ nex ┆ nex ┆ h   ┆ las ┆ las ┆ sch ┆ inS ┆ onS ┆ tra ┆ rec ┆ aID ┆ cap ┆ dir ┆ seq ┆ las ┆ nex ┆ nex ┆ atS ┆ __i ┆ nex ┆ las │
# │ teI ┆ ter ┆ ipm ┆ pID ┆ --- ┆ --- ┆ d   ┆ aci ┆ ad  ┆ ckI ┆ tSt ┆ tSt ┆ tPa ┆ --- ┆ tSt ┆ tPa ┆ edu ┆ erv ┆ che ┆ inI ┆ eiv ┆ --- ┆ tur ┆ ect ┆ --- ┆ tSt ┆ tSt ┆ tSt ┆ top ┆ nde ┆ tSt ┆ tSt │
# │ D   ┆ nID ┆ ent ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ ty  ┆ --- ┆ D   ┆ opI ┆ opE ┆ tte ┆ i64 ┆ opI ┆ tte ┆ leN ┆ ice ┆ dul ┆ D   ┆ eTi ┆ str ┆ eTi ┆ ion ┆ i64 ┆ opE ┆ opE ┆ opP ┆ --- ┆ x_l ┆ opN ┆ opN │
# ...

# %%
def printStops(routeId):
    #Get all stops in the route
    stops = patterns.filter(
        pl.col("id") == routeId 
    ).select(pl.col("stopIDs")).to_series()

    stops = stops[0]
    print(stops)

printStops("2L")
# Out:
# shape: (23,)
# Series: '' [i64]
# [
# 	433
# 	465
# 	466
# 	467
# 	468
# 	436
# 	437
# 	438
# 	439
# 	440
# 	441
# 	442
# 	443
# 	444
# 	445
# 	446
# 	447
# 	448
# 	449
# 	450
# 	431
# 	820
# 	431
# ]

# %%
sub = df.filter(
    (pl.col("routeID") == "2L") &
    (pl.col("equipmentID") == "1002") &
    (pl.col("receiveTime") >= datetime.datetime(2024, 9, 3, 15, 54))
)

sub = sub.with_columns(
    (pl.col("nextStopID").diff().over("equipmentID") != 0).alias("stopChanged")
)

sub
# Out:
# shape: (5_864, 33)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ rou ┆ pat ┆ equ ┆ tri ┆ lat ┆ lng ┆ loa ┆ cap ┆ eLo ┆ blo ┆ nex ┆ nex ┆ nex ┆ h   ┆ las ┆ las ┆ sch ┆ inS ┆ onS ┆ tra ┆ rec ┆ aID ┆ cap ┆ dir ┆ seq ┆ las ┆ nex ┆ nex ┆ atS ┆ __i ┆ nex ┆ las ┆ sto │
# │ teI ┆ ter ┆ ipm ┆ pID ┆ --- ┆ --- ┆ d   ┆ aci ┆ ad  ┆ ckI ┆ tSt ┆ tSt ┆ tPa ┆ --- ┆ tSt ┆ tPa ┆ edu ┆ erv ┆ che ┆ inI ┆ eiv ┆ --- ┆ tur ┆ ect ┆ --- ┆ tSt ┆ tSt ┆ tSt ┆ top ┆ nde ┆ tSt ┆ tSt ┆ pCh │
# │ D   ┆ nID ┆ ent ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ ty  ┆ --- ┆ D   ┆ opI ┆ opE ┆ tte ┆ i64 ┆ opI ┆ tte ┆ leN ┆ ice ┆ dul ┆ D   ┆ eTi ┆ str ┆ eTi ┆ ion ┆ i64 ┆ opE ┆ opE ┆ opP ┆ --- ┆ x_l ┆ opN ┆ opN ┆ ang │
# ...

# %%
#Calculate the time between each stop in the 2L Route

#Select all columns with that routeId and inService
subset = df.filter(
    (pl.col("routeID") == "2L") &
    (pl.col("inService"))
)



#Add stopChanged column
subset = subset.with_columns(
    (
        (pl.col("nextStopID") == pl.col("lastStopID").shift(-1)).over(
            "equipmentID", order_by="receiveTime"
        )
    ).alias("stopChanged")
)

subset = subset.filter(pl.col("stopChanged")).with_columns(
    (pl.col("nextStopID").shift(1) == pl.col("lastStopID"))
    .over("equipmentID", order_by="receiveTime")
    .alias("nextToLast")
)

allDiffs = subset.with_columns(
    (pl.col("receiveTime").diff().over("equipmentID", order_by="receiveTime")).alias(
        "timeDiff"
    )
).filter(pl.col("nextToLast"))


#Add timeDiff column
subset = subset.with_columns(
    (pl.col("receiveTime").diff().over("equipmentID", order_by="receiveTime")).alias(
        "timeDiff"
    )
).filter(pl.col("nextToLast"))

#Filter out any timedeltas above 30 minutes
# subset = subset.filter((pl.col("timeDiff") < datetime.timedelta(minutes=30)))
# allDiffs = subset


subset = subset.group_by("lastStopID", "nextStopID").agg(
        pl.col("lastStopName").first(),
        pl.col("nextStopName").first(),
        pl.col("timeDiff").mean().alias("meanTimeDiff"),
        pl.col("timeDiff").median().alias("medianTimeDiff"),
        pl.col("timeDiff").min().alias("minTimeDiff"),
        pl.col("timeDiff").max().alias("maxTimeDiff"),
)

subset.sort("meanTimeDiff")
# Out:
# shape: (22, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ lastStopID ┆ nextStopID ┆ lastStopNa ┆ nextStopN ┆ meanTimeD ┆ medianTim ┆ minTimeDi ┆ maxTimeDi │
# │ ---        ┆ ---        ┆ me         ┆ ame       ┆ iff       ┆ eDiff     ┆ ff        ┆ ff        │
# │ i64        ┆ i64        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ str        ┆ str       ┆ duration[ ┆ duration[ ┆ duration[ ┆ duration[ │
# │            ┆            ┆            ┆           ┆ ns]       ┆ ns]       ┆ ns]       ┆ ns]       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 440        ┆ 441        ┆ Lincoln    ┆ Lincoln   ┆ 26s 52513 ┆ 30s       ┆ 10s       ┆ 1m        │
# │            ┆            ┆ Hwy. at    ┆ Hwy. at   ┆ 9664ns    ┆           ┆           ┆           │
# ...

# %%
allDiffs.filter(
    (pl.col("lastStopID") == 441)&
    (pl.col("nextStopID") == 442) & 
    (pl.col("timeDiff") > datetime.timedelta(minutes=15))
)
# Out:
# shape: (1, 35)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ rou ┆ pat ┆ equ ┆ tri ┆ lat ┆ lng ┆ loa ┆ cap ┆ eLo ┆ blo ┆ nex ┆ nex ┆ nex ┆ h   ┆ las ┆ las ┆ sch ┆ inS ┆ onS ┆ tra ┆ rec ┆ aID ┆ cap ┆ dir ┆ seq ┆ las ┆ nex ┆ nex ┆ atS ┆ __i ┆ nex ┆ las ┆ sto ┆ nex ┆ tim │
# │ teI ┆ ter ┆ ipm ┆ pID ┆ --- ┆ --- ┆ d   ┆ aci ┆ ad  ┆ ckI ┆ tSt ┆ tSt ┆ tPa ┆ --- ┆ tSt ┆ tPa ┆ edu ┆ erv ┆ che ┆ inI ┆ eiv ┆ --- ┆ tur ┆ ect ┆ --- ┆ tSt ┆ tSt ┆ tSt ┆ top ┆ nde ┆ tSt ┆ tSt ┆ pCh ┆ tSt ┆ eDi │
# │ D   ┆ nID ┆ ent ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ ty  ┆ --- ┆ D   ┆ opI ┆ opE ┆ tte ┆ i64 ┆ opI ┆ tte ┆ leN ┆ ice ┆ dul ┆ D   ┆ eTi ┆ str ┆ eTi ┆ ion ┆ i64 ┆ opE ┆ opE ┆ opP ┆ --- ┆ x_l ┆ opN ┆ opN ┆ ang ┆ opI ┆ ff  │
# ...

# %%
sub = df.filter(
    (pl.col("routeID") == "2R") &
    (pl.col("equipmentID") == "1702") &
    (pl.col("inService") == True) &
    (pl.col("receiveTime") >= datetime.datetime(2024, 9, 3, 15, 0))
)

sub = sub.with_columns(
    (pl.col("nextStopID").diff().over("equipmentID") != 0).alias("stopChanged")
)

sub
# Out:
# shape: (5_015, 33)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ rou ┆ pat ┆ equ ┆ tri ┆ lat ┆ lng ┆ loa ┆ cap ┆ eLo ┆ blo ┆ nex ┆ nex ┆ nex ┆ h   ┆ las ┆ las ┆ sch ┆ inS ┆ onS ┆ tra ┆ rec ┆ aID ┆ cap ┆ dir ┆ seq ┆ las ┆ nex ┆ nex ┆ atS ┆ __i ┆ nex ┆ las ┆ sto │
# │ teI ┆ ter ┆ ipm ┆ pID ┆ --- ┆ --- ┆ d   ┆ aci ┆ ad  ┆ ckI ┆ tSt ┆ tSt ┆ tPa ┆ --- ┆ tSt ┆ tPa ┆ edu ┆ erv ┆ che ┆ inI ┆ eiv ┆ --- ┆ tur ┆ ect ┆ --- ┆ tSt ┆ tSt ┆ tSt ┆ top ┆ nde ┆ tSt ┆ tSt ┆ pCh │
# │ D   ┆ nID ┆ ent ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ ty  ┆ --- ┆ D   ┆ opI ┆ opE ┆ tte ┆ i64 ┆ opI ┆ tte ┆ leN ┆ ice ┆ dul ┆ D   ┆ eTi ┆ str ┆ eTi ┆ ion ┆ i64 ┆ opE ┆ opE ┆ opP ┆ --- ┆ x_l ┆ opN ┆ opN ┆ ang │
# ...

# %%
#Calculate the time between each stop in the 2R Route

#Select all columns with that routeId and inService
subset = df.filter(
    (pl.col("routeID") == "2R") &
    (pl.col("inService") == True)
)

#Add stopChanged column
subset = subset.with_columns(
    (pl.col("nextStopID").diff(-1).over("equipmentID") != 0).alias("stopChanged")
)

#Add timeDiff column
subset = subset.filter(pl.col("stopChanged") == True).with_columns(
    (pl.col("receiveTime").diff().over("equipmentID")).alias("timeDiff")
)

#Filter out any timedeltas above 30 minutes
subset = subset.filter((pl.col("timeDiff") < datetime.timedelta(minutes=30)))

subset = subset.group_by("lastStopID", "nextStopID").agg(
        pl.col("lastStopName").first(),
        pl.col("nextStopName").first(),
        pl.col("timeDiff").mean().alias("meanTimeDiff"),
        pl.col("timeDiff").median().alias("medianTimeDiff"),
        pl.col("timeDiff").min().alias("minTimeDiff"),
        pl.col("timeDiff").max().alias("maxTimeDiff"),
)

subset.sort("meanTimeDiff")
# Out:
# shape: (25, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ lastStopID ┆ nextStopID ┆ lastStopNa ┆ nextStopN ┆ meanTimeD ┆ medianTim ┆ minTimeDi ┆ maxTimeDi │
# │ ---        ┆ ---        ┆ me         ┆ ame       ┆ iff       ┆ eDiff     ┆ ff        ┆ ff        │
# │ i64        ┆ i64        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ str        ┆ str       ┆ duration[ ┆ duration[ ┆ duration[ ┆ duration[ │
# │            ┆            ┆            ┆           ┆ ns]       ┆ ns]       ┆ ns]       ┆ ns]       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0          ┆ 454        ┆ null       ┆ Lincoln   ┆ 10s       ┆ 10s       ┆ 10s       ┆ 10s       │
# │            ┆            ┆            ┆ Hwy. at   ┆           ┆           ┆           ┆           │
# ...

# %%
sub = df.filter(
    (pl.col("routeID") == "3") &
    (pl.col("equipmentID") == "602") &
    (pl.col("inService") == True) &
    (pl.col("receiveTime") >= datetime.datetime(2024, 9, 1, 3, 0))
)

sub = sub.with_columns(
    (pl.col("nextStopID").diff().over("equipmentID") != 0).alias("stopChanged")
)

sub
# Out:
# shape: (4_166, 33)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ rou ┆ pat ┆ equ ┆ tri ┆ lat ┆ lng ┆ loa ┆ cap ┆ eLo ┆ blo ┆ nex ┆ nex ┆ nex ┆ h   ┆ las ┆ las ┆ sch ┆ inS ┆ onS ┆ tra ┆ rec ┆ aID ┆ cap ┆ dir ┆ seq ┆ las ┆ nex ┆ nex ┆ atS ┆ __i ┆ nex ┆ las ┆ sto │
# │ teI ┆ ter ┆ ipm ┆ pID ┆ --- ┆ --- ┆ d   ┆ aci ┆ ad  ┆ ckI ┆ tSt ┆ tSt ┆ tPa ┆ --- ┆ tSt ┆ tPa ┆ edu ┆ erv ┆ che ┆ inI ┆ eiv ┆ --- ┆ tur ┆ ect ┆ --- ┆ tSt ┆ tSt ┆ tSt ┆ top ┆ nde ┆ tSt ┆ tSt ┆ pCh │
# │ D   ┆ nID ┆ ent ┆ --- ┆ f64 ┆ f64 ┆ --- ┆ ty  ┆ --- ┆ D   ┆ opI ┆ opE ┆ tte ┆ i64 ┆ opI ┆ tte ┆ leN ┆ ice ┆ dul ┆ D   ┆ eTi ┆ str ┆ eTi ┆ ion ┆ i64 ┆ opE ┆ opE ┆ opP ┆ --- ┆ x_l ┆ opN ┆ opN ┆ ang │
# ...

# %%
#Calculate the time between each stop in the 3 Route

#Select all columns with that routeId and inService
subset = df.filter(
    (pl.col("routeID") == "3") &
    (pl.col("inService") == True)
)

#Add stopChanged column
subset = subset.with_columns(
    (pl.col("nextStopID").diff(-1).over("equipmentID") != 0).alias("stopChanged")
)

#Add timeDiff column
subset = subset.filter(pl.col("stopChanged") == True).with_columns(
    (pl.col("receiveTime").diff().over("equipmentID")).alias("timeDiff")
)

#Filter out any timedeltas above 30 minutes
subset = subset.filter((pl.col("timeDiff") < datetime.timedelta(minutes=30)))

subset = subset.group_by("lastStopID", "nextStopID").agg(
        pl.col("lastStopName").first(),
        pl.col("nextStopName").first(),
        pl.col("timeDiff").mean().alias("meanTimeDiff"),
        pl.col("timeDiff").median().alias("medianTimeDiff"),
        pl.col("timeDiff").min().alias("minTimeDiff"),
        pl.col("timeDiff").max().alias("maxTimeDiff"),
)

subset.sort("meanTimeDiff")
# Out:
# shape: (20, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ lastStopID ┆ nextStopID ┆ lastStopNa ┆ nextStopN ┆ meanTimeD ┆ medianTim ┆ minTimeDi ┆ maxTimeDi │
# │ ---        ┆ ---        ┆ me         ┆ ame       ┆ iff       ┆ eDiff     ┆ ff        ┆ ff        │
# │ i64        ┆ i64        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ str        ┆ str       ┆ duration[ ┆ duration[ ┆ duration[ ┆ duration[ │
# │            ┆            ┆            ┆           ┆ ns]       ┆ ns]       ┆ ns]       ┆ ns]       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 503        ┆ 504        ┆ Blackhawk  ┆ Blackhawk ┆ 21s 45614 ┆ 20s       ┆ 10s       ┆ 50s       │
# │            ┆            ┆ Rd. at     ┆ Rd. at    ┆ 0350ns    ┆           ┆           ┆           │
# ...
