# %%
import datetime
import gzip
import json
from pathlib import Path
from io import SEEK_END
import struct
import polars as pl
import zipfile

def parse_filename(fname):
    ts_str, rest = Path(fname).name.rsplit("-", 1)
    part = int(rest.split(".", 1)[0])
    ts = datetime.datetime.strptime(ts_str, "%Y-%m-%d_%H_%M_%S")
    return ts, part
  
def get_uncompressed_size(gzf):
    # !!! this is brittle, assumes < 4GB files which should be ok for now
    gzf.seek(-4, SEEK_END)
    uncompressed_size = struct.unpack("I", gzf.read(4))[0]
    gzf.seek(0)
    return uncompressed_size


def get_num_stations(gzf):
    with gzip.GzipFile(fileobj=gzf) as f:
        d = json.load(f)
        if "data" in d and "supply" in d["data"] and "stations" in d["data"]["supply"]:
            return len(d["data"]["supply"]["stations"])
    return 0

def get_data(gzf):
    gzf.seek(0)
    with gzip.GzipFile(fileobj=gzf) as f:
        d = json.load(f)
        return d


zf = zipfile.ZipFile("2024-11-08-compressed.zip", "r")

for i, entry in enumerate(zf.infolist()):
    if entry.is_dir():
        continue
    ts, part_num = parse_filename(entry.filename)
    print(entry.filename)
    print(" ", ts, part_num)
    with zf.open(entry.filename) as f:
        compressed_sz = entry.file_size
        uncompressed_sz = get_uncompressed_size(f)
        print(" ", compressed_sz, uncompressed_sz)

        num_stations = get_num_stations(f)
        d = get_data(f)
        print(" ", num_stations)
    if i >= 10:
        break
# Out:
# 2024-11-08/2024-11-08_03_56_29-1.json.gz
#   2024-11-08 03:56:29 1
#   18918 262073
#   0
# 2024-11-08/2024-11-08_03_57_29-1.json.gz
#   2024-11-08 03:57:29 1
#   18994 261615
#   0
# 2024-11-08/2024-11-08_03_58_29-1.json.gz
#   2024-11-08 03:58:29 1
#   18943 261447
#   0
# 2024-11-08/2024-11-08_03_59_30-1.json.gz
#   2024-11-08 03:59:30 1
#   19057 262503
#   0
# 2024-11-08/2024-11-08_04_00_30-1.json.gz
#   2024-11-08 04:00:30 1
#   18943 261230
#   0
# 2024-11-08/2024-11-08_04_01_30-4.json.gz
#   2024-11-08 04:01:30 4
#   12151 163608
#   0
# 2024-11-08/2024-11-08_04_02_30-4.json.gz
#   2024-11-08 04:02:30 4
#   12116 163168
#   0
# 2024-11-08/2024-11-08_04_03_30-4.json.gz
#   2024-11-08 04:03:30 4
#   12026 161819
#   0
# 2024-11-08/2024-11-08_04_04_30-4.json.gz
#   2024-11-08 04:04:30 4
#   12019 161831
#   0
# 2024-11-08/2024-11-08_04_05_30-4.json.gz
#   2024-11-08 04:05:30 4
#   12060 162275
#   0

# %%
df = pl.DataFrame(d['data']['supply']['rideables'])
df
# Out:
# shape: (364, 7)
# ┌──────────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ rideableId   ┆ rideableName ┆ location    ┆ rideableTyp ┆ photoUrl    ┆ batteryStat ┆ __typename │
# │ ---          ┆ ---          ┆ ---         ┆ e           ┆ ---         ┆ us          ┆ ---        │
# │ str          ┆ str          ┆ struct[3]   ┆ ---         ┆ str         ┆ ---         ┆ str        │
# │              ┆              ┆             ┆ str         ┆             ┆ struct[3]   ┆            │
# ╞══════════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ 189114637926 ┆ ···-3706     ┆ {41.903084, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{15,"miles ┆ Rideable   │
# │ 0463558      ┆              ┆ -87.757459, ┆ KE          ┆ .lyft.com/s ┆ ","Distance ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ "},52,"B…   ┆            │
# │ 189114651509 ┆ ···-5342     ┆ {41.922262, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{8,"miles" ┆ Rideable   │
# │ 5258276      ┆              ┆ -87.687727, ┆ KE          ┆ .lyft.com/s ┆ ,"Distance" ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ },34,"Ba…   ┆            │
# │ 189114651856 ┆ ···-6795     ┆ {41.958865, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{8,"miles" ┆ Rideable   │
# │ 5821062      ┆              ┆ -87.784335, ┆ KE          ┆ .lyft.com/s ┆ ,"Distance" ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ },36,"Ba…   ┆            │
# │ 189114651866 ┆ ···-2966     ┆ {41.914121, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{1,"miles" ┆ Rideable   │
# │ 8050936      ┆              ┆ -87.627849, ┆ KE          ┆ .lyft.com/s ┆ ,"Distance" ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ },18,"Ba…   ┆            │
# │ 189114651906 ┆ ···-9172     ┆ {41.998183, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{19,"miles ┆ Rideable   │
# │ 2372058      ┆              ┆ -87.656597, ┆ KE          ┆ .lyft.com/s ┆ ","Distance ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ "},61,"B…   ┆            │
# │ …            ┆ …            ┆ …           ┆ …           ┆ …           ┆ …           ┆ …          │
# │ 192738502779 ┆ ···-0036     ┆ {41.902288, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{8,"miles" ┆ Rideable   │
# │ 8625932      ┆              ┆ -87.699462, ┆ KE          ┆ .lyft.com/s ┆ ,"Distance" ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ },36,"Ba…   ┆            │
# │ 192738512606 ┆ ···-2564     ┆ {41.739154, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{4,"miles" ┆ Rideable   │
# │ 5828480      ┆              ┆ -87.554049, ┆ KE          ┆ .lyft.com/s ┆ ,"Distance" ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ },26,"Ba…   ┆            │
# │ 192738514614 ┆ ···-5516     ┆ {41.913645, ┆ ELECTRIC_BI ┆ https://cdn ┆ {{12,"miles ┆ Rideable   │
# │ 9317198      ┆              ┆ -87.71165," ┆ KE          ┆ .lyft.com/s ┆ ","Distance ┆            │
# │              ┆              ┆ Location…   ┆             ┆ tatic/la…   ┆ "},44,"B…   ┆            │
# │ 194738233350 ┆ ···-940      ┆ {41.865063, ┆ ELECTRIC_SC ┆ https://cdn ┆ {{8,"miles" ┆ Rideable   │
# │ 7678226      ┆              ┆ -87.71458," ┆ OOTER       ┆ .lyft.com/s ┆ ,"Distance" ┆            │
# │              ┆              ┆ Location…   ┆             ┆ tatic/la…   ┆ },44,"Ba…   ┆            │
# │ 194882815060 ┆ ···-996      ┆ {41.859886, ┆ ELECTRIC_SC ┆ https://cdn ┆ {{42,"miles ┆ Rideable   │
# │ 4881870      ┆              ┆ -87.708766, ┆ OOTER       ┆ .lyft.com/s ┆ ","Distance ┆            │
# │              ┆              ┆ "Locatio…   ┆             ┆ tatic/la…   ┆ "},95,"B…   ┆            │
# └──────────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴────────────┘
